# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Atmospheric-Boundary-Layer/blob/main/LIDAR/Extinction(355).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Atmospheric-Boundary-Layer/main/DATA/E355.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             Z      LR20      LR40      LR60      LR80     LR100     LR120
# 0        60.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1        67.5 -0.000160 -0.000320 -0.000479 -0.000639 -0.000799 -0.000959
# 2        75.0 -0.000160 -0.000319 -0.000479 -0.000639 -0.000798 -0.000958
# 3        82.5 -0.000160 -0.000319 -0.000479 -0.000638 -0.000798 -0.000957
# 4        90.0 -0.000159 -0.000319 -0.000478 -0.000638 -0.000797 -0.000957
# ...       ...       ...       ...       ...       ...       ...       ...
# 3988  29970.0 -0.000002 -0.000005 -0.000007 -0.000009 -0.000011 -0.000014
# 3989  29977.5 -0.000002 -0.000005 -0.000007 -0.000009 -0.000011 -0.000014
# 3990  29985.0 -0.000002 -0.000005 -0.000007 -0.000009 -0.000011 -0.000014
# 3991  29992.5 -0.000002 -0.000004 -0.000007 -0.000009 -0.000011 -0.000013
# 3992  30000.0 -0.000002 -0.000004 -0.000007 -0.000009 -0.000011 -0.000013
#
# [3993 rows x 7 columns]

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Extinction Coeff. [$Mm^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR60'][27:50], df['Z'][27:50], 'g', linestyle = ':' , alpha=0.5)
plt.plot(df['LR60'][50:3993], df['Z'][50:3993], 'g', label='LR=60')

plt.plot(df['LR40'][27:50], df['Z'][27:50], 'r', linestyle = ':' , alpha=0.5)
plt.plot(df['LR40'][50:3993], df['Z'][50:3993], 'r', label='LR=40')

plt.plot(df['LR20'][27:50], df['Z'][27:50], 'black', linestyle = ':' , alpha=0.5)
plt.plot(df['LR20'][50:3993], df['Z'][50:3993], 'black', label='LR=20')

plt.ylim(0,4500)
plt.xticks(np.arange(0,0.0004,0.0001))
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Relative Change %')
plt.ylabel('Hight [m]')

c60 = (df['LR60'][85:3993] - df['LR60'][85:3993]) / df['LR60'][85:3993]
c40 = (df['LR40'][85:3993] - df['LR60'][85:3993]) / df['LR60'][85:3993]
c20 = (df['LR20'][85:3993] - df['LR60'][85:3993]) / df['LR60'][85:3993]

plt.plot(c60*100, df['Z'][85:3993], 'g', label='LR=60')

plt.plot(c40*100, df['Z'][85:3993], 'r', label='LR=40')

plt.plot(c20*100, df['Z'][85:3993], 'black', label='LR=20')

plt.ylim(0,4500)
plt.xlim(-120,120)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Absolute Change [$Mm^{-1} sr^{-1}$]')
plt.ylabel('Hight [m]')

c120 = abs(df['LR120'][85:3993] - df['LR60'][85:3993]) 
c100 = abs(df['LR100'][85:3993] - df['LR60'][85:3993]) 
c80 = abs(df['LR80'][85:3993] - df['LR60'][85:3993]) 
c60 = abs(df['LR60'][85:3993] - df['LR60'][85:3993]) 
c40 = abs(df['LR40'][85:3993] - df['LR60'][85:3993]) 
c20 = abs(df['LR20'][85:3993] - df['LR60'][85:3993]) 


plt.plot(c60, df['Z'][85:3993], 'g', label='LR=60')

plt.plot(c40, df['Z'][85:3993], 'r', label='LR=40')

plt.plot(c20, df['Z'][85:3993], 'black', label='LR=20')

plt.ylim(0,4500)
plt.legend()

plt.show()
