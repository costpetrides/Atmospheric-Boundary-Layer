# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Atmospheric-Boundary-Layer/blob/main/LIDAR/Extinction(532).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Atmospheric-Boundary-Layer/main/DATA/E532.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             Z          LR20          LR40      LR60      LR80     LR100  \
# 0        60.0  0.000000e+00  0.000000e+00  0.000000  0.000000  0.000000
# 1        67.5 -3.168360e-05 -6.336720e-05 -0.000095 -0.000127 -0.000158
# 2        75.0 -3.166080e-05 -6.332160e-05 -0.000095 -0.000127 -0.000158
# 3        82.5 -3.163800e-05 -6.327600e-05 -0.000095 -0.000127 -0.000158
# 4        90.0 -3.161520e-05 -6.323040e-05 -0.000095 -0.000126 -0.000158
# ...       ...           ...           ...       ...       ...       ...
# 3988  29970.0 -4.477050e-07 -8.954090e-07 -0.000001 -0.000002 -0.000002
# 3989  29977.5 -4.471690e-07 -8.943380e-07 -0.000001 -0.000002 -0.000002
# 3990  29985.0 -4.466360e-07 -8.932720e-07 -0.000001 -0.000002 -0.000002
# 3991  29992.5 -4.461020e-07 -8.922040e-07 -0.000001 -0.000002 -0.000002
# 3992  30000.0 -4.455690e-07 -8.911370e-07 -0.000001 -0.000002 -0.000002
#
#          LR120
# 0     0.000000
# 1    -0.000190
# 2    -0.000190
# 3    -0.000190
# 4    -0.000190
# ...        ...
# 3988 -0.000003
# 3989 -0.000003
# 3990 -0.000003
# 3991 -0.000003
# 3992 -0.000003
#
# [3993 rows x 7 columns]

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Ectinction Coeff. [$Mm^{-1}$]')
plt.ylabel('Hight [m]')
  
plt.plot(df['LR120'][85:3993], df['Z'][85:3993], 'purple', label='LR=120') 
plt.plot(df['LR100'][85:3993], df['Z'][85:3993], 'c', label='LR=100')
plt.plot(df['LR80'][85:3993], df['Z'][85:3993], 'b', label='LR=80')
plt.plot(df['LR60'][85:3993], df['Z'][85:3993], 'g', label='LR=60')
plt.plot(df['LR40'][85:3993], df['Z'][85:3993], 'r', label='LR=40')
plt.plot(df['LR20'][85:3993], df['Z'][85:3993], 'black', label='LR=20')

plt.ylim(0,5000)
plt.xlim(0,0.0001)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Relative Change %')
plt.ylabel('Hight [m]')

c120 = (df['LR120'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]
c100 = (df['LR100'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]
c80 = (df['LR80'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]
c60 = (df['LR60'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]
c40 = (df['LR40'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]
c20 = (df['LR20'][50:3993] - df['LR60'][50:3993]) / df['LR60'][50:3993]

plt.plot(c120*100, df['Z'][50:3993], 'purple', label='LR=120') 

plt.plot(c100*100, df['Z'][50:3993], 'c', label='LR=100')

plt.plot(c80*100, df['Z'][50:3993], 'b', label='LR=80')

plt.plot(c60*100, df['Z'][50:3993], 'g', label='LR=60')

plt.plot(c40*100, df['Z'][50:3993], 'r', label='LR=40')

plt.plot(c20*100, df['Z'][50:3993], 'black', label='LR=20')

plt.ylim(0,5000)
plt.xlim(-60,60)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Absolute Change [$Mm^{-1} sr^{-1}$]')
plt.ylabel('Hight [m]')

c120 = abs(df['LR120'][50:3993] - df['LR60'][50:3993]) 
c100 = abs(df['LR100'][50:3993] - df['LR60'][50:3993]) 
c80 = abs(df['LR80'][50:3993] - df['LR60'][50:3993]) 
c60 = abs(df['LR60'][50:3993] - df['LR60'][50:3993]) 
c40 = abs(df['LR40'][50:3993] - df['LR60'][50:3993]) 
c20 = abs(df['LR20'][50:3993] - df['LR60'][50:3993]) 

plt.plot(c120, df['Z'][50:3993], 'purple', label='LR=120') 

plt.plot(c100, df['Z'][50:3993], 'c', label='LR=100')

plt.plot(c80, df['Z'][50:3993], 'b', label='LR=80')

plt.plot(c60, df['Z'][50:3993], 'g', label='LR=60')

plt.plot(c40, df['Z'][50:3993], 'r', label='LR=40')

plt.plot(c20, df['Z'][50:3993], 'black', label='LR=20')

plt.ylim(0,6000)
plt.legend()

plt.show()
