# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Atmospheric-Boundary-Layer/blob/main/LIDAR/BackScatter(1064).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Atmospheric-Boundary-Layer/main/DATA/B1064.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             Z          LR20          LR40          LR60          LR80  \
# 0        60.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1        67.5 -9.900000e-08 -9.900000e-08 -9.900000e-08 -9.900000e-08
# 2        75.0 -9.890000e-08 -9.890000e-08 -9.890000e-08 -9.890000e-08
# 3        82.5 -9.890000e-08 -9.890000e-08 -9.890000e-08 -9.890000e-08
# 4        90.0 -9.880000e-08 -9.880000e-08 -9.880000e-08 -9.880000e-08
# ...       ...           ...           ...           ...           ...
# 3988  29970.0 -1.400000e-09 -1.400000e-09 -1.400000e-09 -1.400000e-09
# 3989  29977.5 -1.400000e-09 -1.400000e-09 -1.400000e-09 -1.400000e-09
# 3990  29985.0 -1.400000e-09 -1.400000e-09 -1.400000e-09 -1.400000e-09
# 3991  29992.5 -1.390000e-09 -1.390000e-09 -1.390000e-09 -1.390000e-09
# 3992  30000.0 -1.390000e-09 -1.390000e-09 -1.390000e-09 -1.390000e-09
#
#              LR100         LR120
# 0     0.000000e+00  0.000000e+00
# 1    -9.900000e-08 -9.900000e-08
# ...

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Backscatter Coeff. [$Mm^{-1} sr^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR120'][0:270], df['Z'][0:270], 'purple', linestyle = '--' )   
plt.plot(df['LR120'][270:3993], df['Z'][270:3993], 'purple', label='LR=120') 

plt.plot(df['LR100'][0:270], df['Z'][0:270], 'c', linestyle = '--')
plt.plot(df['LR100'][270:3993], df['Z'][270:3993], 'c', label='LR=100')

plt.plot(df['LR80'][0:270], df['Z'][0:270], 'b', linestyle = '--')
plt.plot(df['LR80'][270:3993], df['Z'][270:3993], 'b', label='LR=80')

plt.plot(df['LR60'][0:270], df['Z'][0:270], 'g', linestyle = '--')
plt.plot(df['LR60'][270:3993], df['Z'][270:3993], 'g', label='LR=60')

plt.plot(df['LR40'][0:270], df['Z'][0:270], 'r', linestyle = '--')
plt.plot(df['LR40'][270:3993], df['Z'][270:3993], 'r', label='LR=40')

plt.plot(df['LR20'][0:270], df['Z'][0:270], 'black', linestyle = '--')
plt.plot(df['LR20'][50:3993], df['Z'][50:3993], 'black', label='LR=20')

plt.ylim(0,5000)
plt.legend()

plt.show()

# %% [markdown]
# # Relative Change

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Relative Change')
plt.ylabel('Hight [m]')

c120 = (df['LR120'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c100 = (df['LR100'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c80 = (df['LR80'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c60 = (df['LR60'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c40 = (df['LR40'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c20 = (df['LR20'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]


plt.plot(c120, df['Z'][270:3993], 'purple', label='LR=120') 

plt.plot(c100, df['Z'][270:3993], 'c', label='LR=100')

plt.plot(c80, df['Z'][270:3993], 'b', label='LR=80')

plt.plot(c60, df['Z'][270:3993], 'g', label='LR=60')

plt.plot(c40, df['Z'][270:3993], 'r', label='LR=40')

plt.plot(c20, df['Z'][270:3993], 'black', label='LR=20')

plt.ylim(0,6000)
plt.xlim(-0.1,0.1)
plt.legend()

plt.show()

# %% [markdown]
# # Absolute change

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Absolute Change')
plt.ylabel('Hight [m]')

c120 = abs(df['LR120'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c100 = abs(df['LR100'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c80 = abs(df['LR80'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c60 = abs(df['LR60'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c40 = abs(df['LR40'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]
c20 = abs(df['LR20'][270:3993] - df['LR60'][270:3993]) / df['LR60'][270:3993]


plt.plot(c120, df['Z'][270:3993], 'purple', label='LR=120') 

plt.plot(c100, df['Z'][270:3993], 'c', label='LR=100')

plt.plot(c80, df['Z'][270:3993], 'b', label='LR=80')

plt.plot(c60, df['Z'][270:3993], 'g', label='LR=60')

plt.plot(c40, df['Z'][270:3993], 'r', label='LR=40')

plt.plot(c20, df['Z'][270:3993], 'black', label='LR=20')

plt.ylim(0,6000)
plt.xlim(-0.1,0.1)
plt.legend()

plt.show()
