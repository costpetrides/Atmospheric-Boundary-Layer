# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Atmospheric-Boundary-Layer/blob/main/LIDAR/B532nm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Atmospheric-Boundary-Layer/main/DATA/B532.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             Z          LR20          LR40          LR60          LR80  \
# 0        60.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1        67.5 -1.580000e-06 -1.580000e-06 -1.580000e-06 -1.580000e-06
# 2        75.0 -1.580000e-06 -1.580000e-06 -1.580000e-06 -1.580000e-06
# 3        82.5 -1.580000e-06 -1.580000e-06 -1.580000e-06 -1.580000e-06
# 4        90.0 -1.580000e-06 -1.580000e-06 -1.580000e-06 -1.580000e-06
# ...       ...           ...           ...           ...           ...
# 3988  29970.0 -2.240000e-08 -2.240000e-08 -2.240000e-08 -2.240000e-08
# 3989  29977.5 -2.240000e-08 -2.240000e-08 -2.240000e-08 -2.240000e-08
# 3990  29985.0 -2.230000e-08 -2.230000e-08 -2.230000e-08 -2.230000e-08
# 3991  29992.5 -2.230000e-08 -2.230000e-08 -2.230000e-08 -2.230000e-08
# 3992  30000.0 -2.230000e-08 -2.230000e-08 -2.230000e-08 -2.230000e-08
#
#              LR100         LR120
# 0     0.000000e+00  0.000000e+00
# 1    -1.580000e-06 -1.580000e-06
# ...

# %% [markdown]
# # Backscatter Coefficient.

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Backscatter Coeff. [$Mm^{-1} sr^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR120'], df['Z'], 'purple', label='LR=120')
plt.plot(df['LR100'], df['Z'], 'c', label='LR=100')
plt.plot(df['LR80'], df['Z'], 'b', label='LR=80')
plt.plot(df['LR60'], df['Z'], 'g', label='LR=60')
plt.plot(df['LR40'], df['Z'], 'r', label='LR=40')
plt.plot(df['LR20'], df['Z'], 'black', label='LR=20')

plt.ylim(0,5000)
plt.xlim(0,4.5e-6)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Backscatter Coeff. [$Mm^{-1} sr^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR120'][0:50], df['Z'][0:50], 'purple', linestyle = ':', alpha=0.5)   
plt.plot(df['LR120'][50:3993], df['Z'][50:3993], 'purple', label='LR=120') 

plt.plot(df['LR100'][0:50], df['Z'][0:50], 'c', linestyle = ':', alpha=0.5)
plt.plot(df['LR100'][50:3993], df['Z'][50:3993], 'c', label='LR=100')

plt.plot(df['LR80'][0:50], df['Z'][0:50], 'b', linestyle = ':', alpha=0.5)
plt.plot(df['LR80'][50:3993], df['Z'][50:3993], 'b', label='LR=80')

plt.plot(df['LR60'][0:50], df['Z'][0:50], 'g', linestyle = ':', alpha=0.5)
plt.plot(df['LR60'][50:3993], df['Z'][50:3993], 'g', label='LR=60')

plt.plot(df['LR40'][0:50], df['Z'][0:50], 'r', linestyle = ':', alpha=0.5)
plt.plot(df['LR40'][50:3993], df['Z'][50:3993], 'r', label='LR=40')

plt.plot(df['LR20'][0:50], df['Z'][0:50], 'black', linestyle = ':', alpha=0.5)
plt.plot(df['LR20'][50:3993], df['Z'][50:3993], 'black', label='LR=20')


plt.ylim(0,5500)
plt.xlim(0,4.5e-6)
plt.legend()

plt.show()

# %% [markdown]
# # Extinction Coefficient

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Extinction Coeff. [$Mm^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR120']*120, df['Z'], 'purple', label='LR=120')
plt.plot(df['LR100']*100, df['Z'], 'c', label='LR=100')
plt.plot(df['LR80']*80, df['Z'], 'b', label='LR=80')
plt.plot(df['LR60']*60, df['Z'], 'g', label='LR=60')
plt.plot(df['LR40']*40, df['Z'], 'r', label='LR=40')
plt.plot(df['LR20']*20, df['Z'], 'black', label='LR=20')

plt.ylim(0,5000)
plt.xlim(0,2.5e-4)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(4,4))

plt.xlabel('Extinction Coeff. [$Mm^{-1}$]')
plt.ylabel('Hight [m]')

plt.plot(df['LR120'][0:50]*120, df['Z'][0:50], 'purple', linestyle = ':', alpha=0.5)   
plt.plot(df['LR120'][50:3993]*120, df['Z'][50:3993], 'purple', label='LR=120') 

plt.plot(df['LR100'][0:50]*100, df['Z'][0:50], 'c', linestyle = ':', alpha=0.5)
plt.plot(df['LR100'][50:3993]*100, df['Z'][50:3993], 'c', label='LR=100')

plt.plot(df['LR80'][0:50]*80, df['Z'][0:50], 'b', linestyle = ':', alpha=0.5)
plt.plot(df['LR80'][50:3993]*80, df['Z'][50:3993], 'b', label='LR=80')

plt.plot(df['LR60'][0:50]*60, df['Z'][0:50], 'g', linestyle = ':', alpha=0.5)
plt.plot(df['LR60'][50:3993]*60, df['Z'][50:3993], 'g', label='LR=60')

plt.plot(df['LR40'][0:50]*40, df['Z'][0:50], 'r', linestyle = ':', alpha=0.5)
plt.plot(df['LR40'][50:3993]*40, df['Z'][50:3993], 'r', label='LR=40')

plt.plot(df['LR20'][0:50]*20, df['Z'][0:50], 'black', linestyle = ':', alpha=0.5)
plt.plot(df['LR20'][50:3993]*20, df['Z'][50:3993], 'black', label='LR=20')

plt.ylim(0,5000)
plt.xlim(0,2.5e-4)
plt.legend()

plt.show()
