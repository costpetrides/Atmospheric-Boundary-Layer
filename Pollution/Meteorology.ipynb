# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Atmospheric-Boundary-Layer/blob/main/Pollution/Meteorology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Atmospheric-Boundary-Layer/main/DATA/METEO.csv'
df = pd.read_csv(url)
print(df)  
xi=np.arange(0,31,1)
# Out:
#           DAY  Tmin  Tmean  Tmax  Rhmin  Rhmax  Wind
# 0   27-Jun-18  17.9   19.7  21.7     73     92   6.6
# 1   28-Jun-18  17.6   20.3  23.7     72     93  11.7
# 2   29-Jun-18  20.3   23.2  28.4     59     83   9.1
# 3   30-Jun-18  19.6   24.8  28.8     55     87  13.9
# 4    1-Jul-18  22.9   26.4  30.7     46     73  12.0
# 5    2-Jul-18  20.6   25.5  29.9     60     85   5.3
# 6    3-Jul-18  21.8   26.0  29.9     63     89   5.0
# 7    4-Jul-18  22.8   26.6  33.0     53     87   5.1
# 8    5-Jul-18  23.1   27.9  33.3     48     89   7.3
# 9    6-Jul-18  23.0   27.3  30.9     62     84   6.8
# 10   7-Jul-18  23.1   26.7  31.4     58     85   7.6
# 11   8-Jul-18  22.9   26.3  30.4     48     82  16.6
# 12   9-Jul-18  19.4   24.1  31.0     49     88  16.4
# 13  10-Jul-18  19.4   23.8  29.5     55     83  11.7
# 14  11-Jul-18  21.2   25.8  30.6     58     86   8.3
# 15  12-Jul-18  21.1   26.6  31.8     53     83   4.9
# 16  13-Jul-18  22.5   27.5  31.9     60     86   6.7
# 17  14-Jul-18  25.7   28.7  32.2     43     80  15.3
# 18  15-Jul-18  24.8   28.0  32.5     39     72  13.5
# 19  16-Jul-18  23.2   27.8  32.9     44     80  12.3
# 20  17-Jul-18  24.1   27.6  35.6     41     79   6.9
# 21  18-Jul-18  24.4   27.3  30.7     44     74  24.7
# 22  19-Jul-18  23.0   26.2  29.0     48     66  26.4
# 23  20-Jul-18  22.2   26.3  30.7     51     77  15.0
# 24  21-Jul-18  21.6   26.7  32.1     44     81  10.7
# 25  22-Jul-18  21.6   28.1  36.1     40     86   3.9
# 26  23-Jul-18  19.4   25.6  35.0     39     88   8.0
# 27  24-Jul-18  21.0   24.7  29.3     58     93  11.3
# 28  25-Jul-18  22.7   25.8  29.4     62     89  14.0
# 29  26-Jul-18  22.3   25.1  29.9     61     92   7.8
# 30  27-Jul-18  21.1   25.0  30.3     67     94   4.1

# %%
plt.figure(figsize=(13,2))

plt.ylabel('Temperature  $[^{o}C]$')
plt.xlabel('Days')


plt.plot(df['DAY'], df['Tmean'], 'g', label='Temperature')
plt.scatter(df['DAY'], df['Tmean'], color='g')
plt.fill_between(df['DAY'], df['Tmin'], df['Tmax'], alpha=0.2, label='min-max')
plt.legend()

plt.xlim(df['DAY'][0] , df['DAY'][30])
plt.ylim(0,50)

plt.xticks(rotation=90)

p = np.polyfit(xi, df['Tmean'], 1)
plt.plot(df['DAY'], xi*p[0]+p[1],color='slategray')


plt.show()

# %%
plt.figure(figsize=(13,2))

plt.ylabel('RH %')
plt.xlabel('Days')

plt.plot(df['DAY'], df['Rhmax'], 'blue', label='RH - max')
plt.scatter(df['DAY'], df['Rhmax'], color='blue')
plt.plot(df['DAY'], df['Rhmin'], 'red', label='RH - min')
plt.scatter(df['DAY'], df['Rhmin'], color='red')

plt.legend()

plt.xlim(df['DAY'][0] , df['DAY'][30])
plt.ylim(0,100)
plt.xticks(rotation=90)

p = np.polyfit(xi, df['Rhmin'], 1)
plt.plot(df['DAY'], xi*p[0]+p[1],color='slategray')

p = np.polyfit(xi, df['Rhmax'], 1)
plt.plot(df['DAY'], xi*p[0]+p[1],color='slategray')


plt.show()

# %%
plt.figure(figsize=(13,2))

plt.ylabel('Wind Velocity  $[Km/hr]$')
plt.xlabel('Days')

plt.plot(df['DAY'], df['Wind'], 'purple', label='Average wind Velocity')
plt.scatter(df['DAY'], df['Wind'], color='purple')
plt.legend()

plt.xlim(df['DAY'][0] , df['DAY'][30])
plt.ylim(0,40)

plt.xticks(rotation=90)

p = np.polyfit(xi, df['Wind'], 1)
plt.plot(df['DAY'], xi*p[0]+p[1],color='slategray')

plt.show()
